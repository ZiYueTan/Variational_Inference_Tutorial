# %%
import gc
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ScLdaSimData import ScLdaSimData
from LDA import LDA

# %matplotlib inline

# %% [markdown]
# ## Simulation configuration

# %%
# DEMO: fast tutorial defaults. PAPER: match Tutorial_code figure config.
SCALE = "DEMO"  # set to "PAPER" for publication-scale runs

if SCALE == "PAPER":
    N_CELLS = 10_000
    N_GENES = 5_000
    N_TOPICS = 10
    N_REPS = 100
    MEAN_LIBRARY_SIZE = 500.0
    CAVI_MAX_ITER = 10
    SVI_MAX_STEPS = 100
    PYRO_MAX_STEPS = 100
    BATCH_SIZE = 1000
    EVAL_SIZE = 1000
else:
    N_CELLS = 500
    N_GENES = 300
    N_TOPICS = 5
    N_REPS = 3
    MEAN_LIBRARY_SIZE = 100.0
    CAVI_MAX_ITER = 3
    SVI_MAX_STEPS = 30
    PYRO_MAX_STEPS = 30
    BATCH_SIZE = 100
    EVAL_SIZE = 100

BASE_SEED = 1
ETA_TRUE = 0.05
ALPHA_TRUE = 0.2
ETA_FIT = 0.05
ALPHA_FIT = 0.2
TRAIN_FRACTION = 0.8
TAU0 = 1.0
KAPPA = 0.6
PYRO_LR = 0.1
PYRO_LRD = 0.998
PYRO_NUM_PARTICLES = 1
METHODS = ("CAVI", "SVI", "PYRO")
RESULTS_DIR = Path("../../results/scLDA")

# %%
def run_one_simulation(rep_id, seed):
    sim = ScLdaSimData.simulate(
        n_cells=N_CELLS,
        n_genes=N_GENES,
        n_topics=N_TOPICS,
        mean_library_size=MEAN_LIBRARY_SIZE,
        eta=ETA_TRUE,
        alpha=ALPHA_TRUE,
        seed=seed,
    )
    train_counts, test_counts = sim.train_test_split(TRAIN_FRACTION, seed + 10_000)

    # Seed scheme matches Tutorial_code/VI_simu/scLDA (paper figure).
    lambda_seed = seed + 20_000
    eval_seed = seed + 30_000
    rng = np.random.default_rng(eval_seed)
    eval_indices = np.sort(rng.choice(N_CELLS, size=min(EVAL_SIZE, N_CELLS), replace=False))
    model = LDA(n_topics=N_TOPICS, alpha=ALPHA_FIT, eta=ETA_FIT, seed=lambda_seed)
    history = model.fit(
        train_counts,
        test_counts,
        sim.beta_true,
        methods=METHODS,
        cavi_max_iter=CAVI_MAX_ITER,
        svi_max_steps=SVI_MAX_STEPS,
        pyro_max_steps=PYRO_MAX_STEPS,
        batch_size=BATCH_SIZE,
        tau0=TAU0,
        kappa=KAPPA,
        pyro_lr=PYRO_LR,
        pyro_lrd=PYRO_LRD,
        pyro_num_particles=PYRO_NUM_PARTICLES,
        eval_every_cavi=1,
        eval_every_svi=10,
        eval_every_pyro=10,
        eval_indices=eval_indices,
    )
    history.insert(0, "rep", rep_id)
    history.insert(1, "seed", seed)
    history["n_cells"] = N_CELLS
    history["n_genes"] = N_GENES
    history["epoch"] = history["processed_cells"] / N_CELLS
    gc.collect()
    return history

# %% [markdown]
# ## Run repeated simulations

# %%
histories = []
for rep in range(N_REPS):
    seed = BASE_SEED + rep
    print(f"rep {rep + 1}/{N_REPS}, seed={seed}")
    histories.append(run_one_simulation(rep, seed))

history = pd.concat(histories, ignore_index=True)
history.head()
# Out:
# rep 1/3, seed=1
# rep 2/3, seed=2
# rep 3/3, seed=3
#    rep  seed method  iteration  processed_cells   runtime  lambda_change  \
# 0    0     1   CAVI          1              500  1.706645      59.461825
# 1    0     1   CAVI          2             1000  3.177053       0.661209
# 2    0     1   CAVI          3             1500  4.625332       0.266898
# 3    0     1    SVI         10             1000  1.497164       0.038141
# 4    0     1    SVI         20             2000  2.780950       0.037915
#
#    heldout_loglik  heldout_tokens  heldout_nll  perplexity  topic_tv  \
# 0    -8725.278572          1955.0     4.463058   86.752401  0.654938
# 1    -8126.285354          1955.0     4.156668   63.858372  0.441933
# 2    -7972.153666          1955.0     4.077828   59.017143  0.380428
# 3    -7710.905378          1955.0     3.944197   51.634865  0.122668
# 4    -7661.837117          1955.0     3.919098   50.355018  0.064044
#
#    top_gene_overlap  n_cells  n_genes  epoch
# 0              0.35      500      300    1.0
# 1              0.64      500      300    2.0
# 2              0.66      500      300    3.0
# 3              0.93      500      300    2.0
# 4              0.94      500      300    4.0

# %%
final_rows = (
    history.sort_values(["rep", "method", "runtime", "iteration"])
    .groupby(["rep", "method"], as_index=False)
    .tail(1)
)

summary = (
    final_rows.groupby("method")[
        ["heldout_nll", "topic_tv", "topic_mse", "top_gene_overlap", "runtime"]
    ]
    .agg(["mean", "std", "median"])
)
summary.columns = ["_".join(col) for col in summary.columns]
summary = summary.reset_index()

RESULTS_DIR.mkdir(parents=True, exist_ok=True)
history.to_csv(RESULTS_DIR / "history.csv", index=False)
summary.to_csv(RESULTS_DIR / "summary.csv", index=False)

summary
# Out:
#   method  heldout_nll_mean  heldout_nll_std  heldout_nll_median  \
# 0   CAVI          4.062979         0.088070            4.077828
# 1    SVI          3.926950         0.038248            3.915914
#
#    topic_tv_mean  topic_tv_std  topic_tv_median  top_gene_overlap_mean  \
# 0       0.297851      0.092106         0.314608               0.773333
# 1       0.054011      0.005367         0.055040               0.953333
#
#    top_gene_overlap_std  top_gene_overlap_median  runtime_mean  runtime_std  \
# 0              0.120554                     0.76      4.221303     0.386610
# 1              0.020817                     0.96      3.995195     0.283607
#
#    runtime_median
# 0        4.183721
# 1        4.086482

# %% [markdown]
# Compare how quickly CAVI, SVI, and Pyro recover the true top genes as the number of processed cells increases.

# %%
plot_history = pd.read_csv(RESULTS_DIR / "history.csv")
fig, ax = plt.subplots(figsize=(5.0, 3.6))

for method, method_df in plot_history.groupby("method"):
    curves = []
    for _, rep_df in method_df.groupby("rep"):
        rep_df = rep_df.sort_values("processed_cells").drop_duplicates("processed_cells", keep="last")
        rep_df = rep_df.dropna(subset=["processed_cells", "top_gene_overlap"])
        if not rep_df.empty:
            curves.append(rep_df.set_index("processed_cells")["top_gene_overlap"])

    common_cells = sorted(set.intersection(*[set(c.index) for c in curves])) if curves else []
    if not common_cells:
        continue
    grid = np.asarray(common_cells, dtype=float)
    values = np.vstack([[float(c.loc[v]) for v in common_cells] for c in curves])
    mean = np.nanmean(values, axis=0)
    lo, hi = np.nanquantile(values, [0.10, 0.90], axis=0)

    line, = ax.plot(grid, mean, marker="o", linewidth=2, markersize=3, label=method)
    if values.shape[0] > 1:
        ax.fill_between(grid, lo, hi, alpha=0.22, color=line.get_color())

ax.set_xlabel("Processed cells")
ax.set_ylabel("Top-gene overlap")
ax.set_xscale("log")
ax.grid(alpha=0.25)
ax.legend(frameon=False)
fig.tight_layout()

# %% [markdown]
# Compare topic recovery accuracy over wall-clock runtime using topic total variation distance.

# %%
plot_history = pd.read_csv(RESULTS_DIR / "history.csv")
fig, ax = plt.subplots(figsize=(5.0, 3.6))

for method, method_df in plot_history.groupby("method"):
    rep_frames = []
    for _, rep_df in method_df.groupby("rep"):
        rep_df = rep_df.sort_values("runtime").drop_duplicates("runtime", keep="last")
        rep_df = rep_df.dropna(subset=["runtime", "topic_tv"])
        if not rep_df.empty:
            rep_frames.append(rep_df)

    if not rep_frames:
        continue
    start = max(float(rep_df["runtime"].min()) for rep_df in rep_frames)
    stop = min(float(rep_df["runtime"].max()) for rep_df in rep_frames)
    if stop <= start:
        continue
    grid = np.linspace(start, stop, 80)
    values = np.vstack([
        np.interp(grid, rep_df["runtime"].to_numpy(float), rep_df["topic_tv"].to_numpy(float))
        for rep_df in rep_frames
    ])
    mean = np.nanmean(values, axis=0)
    lo, hi = np.nanquantile(values, [0.10, 0.90], axis=0)

    line, = ax.plot(grid, mean, linewidth=2, label=method)
    if values.shape[0] > 1:
        ax.fill_between(grid, lo, hi, alpha=0.22, color=line.get_color())

ax.set_xlabel("Time (s)")
ax.set_ylabel("Topic TV distance")
ax.grid(alpha=0.25)
ax.legend(frameon=False)
fig.tight_layout()

# %% [markdown]
# Show the runtime cost of each method as a function of the number of processed cells.

# %%
plot_history = pd.read_csv(RESULTS_DIR / "history.csv")
fig, ax = plt.subplots(figsize=(5.0, 3.6))

for method, method_df in plot_history.groupby("method"):
    curves = []
    for _, rep_df in method_df.groupby("rep"):
        rep_df = rep_df.sort_values("processed_cells").drop_duplicates("processed_cells", keep="last")
        rep_df = rep_df.dropna(subset=["processed_cells", "runtime"])
        if not rep_df.empty:
            curves.append(rep_df.set_index("processed_cells")["runtime"])

    common_cells = sorted(set.intersection(*[set(c.index) for c in curves])) if curves else []
    if not common_cells:
        continue
    grid = np.asarray(common_cells, dtype=float)
    values = np.vstack([[float(c.loc[v]) for v in common_cells] for c in curves])
    mean = np.nanmean(values, axis=0)
    lo, hi = np.nanquantile(values, [0.10, 0.90], axis=0)

    line, = ax.plot(grid, mean, marker="o", linewidth=2, markersize=3, label=method)
    if values.shape[0] > 1:
        ax.fill_between(grid, lo, hi, alpha=0.22, color=line.get_color())

ax.set_xlabel("Processed cells")
ax.set_ylabel("Time (s)")
ax.set_xscale("log")
ax.grid(alpha=0.25)
ax.legend(frameon=False)
fig.tight_layout()

# %% [markdown]
# Matched topic MSE $\|\hat\beta_k - \beta^0_{\pi(k)}\|_2^2$ for CAVI, SVI, and Pyro as a function of processed cells.

# %%
plot_history = pd.read_csv(RESULTS_DIR / "history.csv")
fig, ax = plt.subplots(figsize=(5.0, 3.6))

for method, method_df in plot_history.groupby("method"):
    curves = []
    for _, rep_df in method_df.groupby("rep"):
        rep_df = rep_df.sort_values("processed_cells").drop_duplicates("processed_cells", keep="last")
        rep_df = rep_df.dropna(subset=["processed_cells", "topic_mse"])
        if not rep_df.empty:
            curves.append(rep_df.set_index("processed_cells")["topic_mse"])

    common_cells = sorted(set.intersection(*[set(c.index) for c in curves])) if curves else []
    if not common_cells:
        continue
    grid = np.asarray(common_cells, dtype=float)
    values = np.vstack([[float(c.loc[v]) for v in common_cells] for c in curves])
    mean = np.nanmean(values, axis=0)
    lo, hi = np.nanquantile(values, [0.10, 0.90], axis=0)

    line, = ax.plot(grid, mean, marker="o", linewidth=2, markersize=3, label=method)
    if values.shape[0] > 1:
        ax.fill_between(grid, lo, hi, alpha=0.22, color=line.get_color())

ax.set_xlabel("Processed cells")
ax.set_ylabel(r"Topic MSE $\|\hat\beta-\beta^0\|_2^2$")
ax.set_xscale("log")
ax.grid(alpha=0.25)
ax.legend(frameon=False)
fig.tight_layout()

# %% [markdown]
# ### Pyro vs specialized CAVI / SVI
#
# The specialized **CAVI** and **SVI** estimators use hand-derived conjugate Dirichlet mean-field updates (coordinate ascent / natural gradients).
#
# The **Pyro** curve is intentionally a *standard black-box* Autoguide setup: Pyro's `AutoNormal` places a diagonal Normal variational family on the unconstrained latents for both global topics `beta` and local cell usages `theta`, trained with `Trace_ELBO` + Adam. There is **no** conjugate local coordinate-ascent step inside the guide.
#
# This contrast is the practical takeaway: conjugacy-aware CAVI/SVI are typically more accurate per wall-clock update on this model, while AutoGuide Pyro requires almost no model-specific derivation and is the default path when conjugacy is unavailable.
